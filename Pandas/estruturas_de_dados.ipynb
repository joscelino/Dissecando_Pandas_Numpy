# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Series

# %%
s = pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
s
# Out:
# a    0.791827
# b   -0.386517
# c   -0.034182
# d   -0.721045
# e    0.444896
# dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
d = {"b": 1, "a": 0, "c": 2}
d = pd.Series(d)
d
# Out:
# b    1
# a    0
# c    2
# dtype: int64

# %% [markdown]
# #### Manipulando como array

# %%
s[0]
# Out:
# 0.7918273867390665

# %%
s[:3]
# Out:
# a    0.791827
# b   -0.386517
# c   -0.034182
# dtype: float64

# %%
s[s > s.median()]
# Out:
# a    0.791827
# e    0.444896
# dtype: float64

# %%
s[[4, 3, 1]]
# Out:
# e    0.444896
# d   -0.721045
# b   -0.386517
# dtype: float64

# %%
np.exp(s)
# Out:
# a    2.207427
# b    0.679419
# c    0.966395
# d    0.486244
# e    1.560328
# dtype: float64

# %%
s.dtype
# Out:
# dtype('float64')

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.array
# Out:
# <PandasArray>
# [  0.7918273867390665,  -0.3865167210732995, -0.03418214913699817,
#   -0.7210451348388823,   0.4448961805122102]
# Length: 5, dtype: float64

# %%
s.to_numpy()
# Out:
# array([ 0.79182739, -0.38651672, -0.03418215, -0.72104513,  0.44489618])

# %% [markdown]
# #### Manipulando como dicionario

# %%
s["a"]
# Out:
# 0.7918273867390665

# %%
s["e"] = 12.0
s
# Out:
# a     0.791827
# b    -0.386517
# c    -0.034182
# d    -0.721045
# e    12.000000
# dtype: float64

# %%
"e" in s
# Out:
# True

# %%
"f" in s
# Out:
# False

# %%
s.get("f", np.nan)
# Out:
# nan

# %% [markdown]
# #### Operacoes com vetores

# %%
s + s
# Out:
# a     1.583655
# b    -0.773033
# c    -0.068364
# d    -1.442090
# e    24.000000
# dtype: float64

# %%
s * 2
# Out:
# a     1.583655
# b    -0.773033
# c    -0.068364
# d    -1.442090
# e    24.000000
# dtype: float64

# %%
np.exp(s)
# Out:
# a         2.207427
# b         0.679419
# c         0.966395
# d         0.486244
# e    162754.791419
# dtype: float64

# %%
s[1:] + s[:-1]
# Out:
# a         NaN
# b   -0.773033
# c   -0.068364
# d   -1.442090
# e         NaN
# dtype: float64

# %% [markdown]
# #### Name attribute

# %%
s = pd.Series(np.random.randn(5), name="something")
s
# Out:
# 0   -0.918236
# 1   -0.036329
# 2   -0.995290
# 3   -1.288451
# 4   -0.599606
# Name: something, dtype: float64

# %%
s.name
# Out:
# 'something'

# %%
s2 = s.rename("different")
s2.name
# Out:
# 'different'

# %% [markdown]
# #### Dataframe

# %%
d = {
    "one": pd.Series([1.0, 2.0, 3.0], index=["a", "b", "c"]),
    "two": pd.Series([1.0, 2.0, 3.0, 4.0], index=["a", "b", "c", "d"]),
}

# %%
df = pd.DataFrame(d)
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
pd.DataFrame(d, index=["d", "b", "a"])
# Out:
#    one  two
# d  NaN  4.0
# b  2.0  2.0
# a  1.0  1.0

# %%
pd.DataFrame(d, index=["d", "b", "a"], columns=["two", "three"])
# Out:
#    two three
# d  4.0   NaN
# b  2.0   NaN
# a  1.0   NaN

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %% [markdown]
# #### From structured or record array

# %%
data = np.zeros((2,), dtype=[("A", "i4"), ("B", "f4"), ("C", "a10")])
data
# Out:
# array([(0, 0., b''), (0, 0., b'')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
data[:] = [(1, 2.0, "Hello"), (2, 3.0, "World")]
data
# Out:
# array([(1, 2., b'Hello'), (2, 3., b'World')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
pd.DataFrame(data)
# Out:
#    A    B         C
# 0  1  2.0  b'Hello'
# 1  2  3.0  b'World'

# %%
pd.DataFrame(data, index=["first", "second"])
# Out:
#         A    B         C
# first   1  2.0  b'Hello'
# second  2  3.0  b'World'

# %%
pd.DataFrame(data, columns=["C", "A", "B"])
# Out:
#           C  A    B
# 0  b'Hello'  1  2.0
# 1  b'World'  2  3.0

# %% [markdown]
# #### From a list of dicts

# %%
data2 = [{"a": 1, "b": 2}, {"a": 5, "b": 10, "c": 20}]

# %%
pd.DataFrame(data2)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
pd.DataFrame(data2, columns=["a", "b"])
# Out:
#    a   b
# 0  1   2
# 1  5  10

# %% [markdown]
# #### From a dict of tuples

# %%
pd.DataFrame(
    {
        ("a", "b"): {("A", "B"): 1, ("A", "C"): 2},
        ("a", "a"): {("A", "C"): 3, ("A", "B"): 4},
        ("a", "c"): {("A", "B"): 5, ("A", "C"): 6},
        ("b", "a"): {("A", "C"): 7, ("A", "B"): 8},
        ("b", "b"): {("A", "D"): 9, ("A", "B"): 10},
    }
)
# Out:
#        a              b
#        b    a    c    a     b
# A B  1.0  4.0  5.0  8.0  10.0
#   C  2.0  3.0  6.0  7.0   NaN
#   D  NaN  NaN  NaN  NaN   9.0

# %% [markdown]
# #### From a list of namedtuples

# %%
from collections import namedtuple

# %%
Point = namedtuple("Point", "x y")

# %%
pd.DataFrame([Point(0, 0), Point(0, 3), (2, 3)])
# Out:
#    x  y
# 0  0  0
# 1  0  3
# 2  2  3

# %%
Point3D = namedtuple("Point3D", "x y z")

# %%
pd.DataFrame([Point3D(0, 0, 0), Point3D(0, 3, 5), Point(2, 3)])
# Out:
#    x  y    z
# 0  0  0  0.0
# 1  0  3  5.0
# 2  2  3  NaN

# %% [markdown]
# #### From a list of dataclasses

# %%
from dataclasses import make_dataclass

# %%
Point = make_dataclass("Point", [("x", int), ("y", int)])

# %%
pd.DataFrame([Point(0, 0), Point(0, 3), Point(2, 3)])
# Out:
#    x  y
# 0  0  0
# 1  0  3
# 2  2  3

# %% [markdown]
# #### Alternate constructors

# %%
pd.DataFrame.from_dict(dict([("A", [1, 2, 3]), ("B", [4, 5, 6])]))
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
pd.DataFrame.from_dict(
    dict([("A", [1, 2, 3]), ("B", [4, 5, 6])]),
    orient="index",
    columns=["one", "two", "three"],
)
# Out:
#    one  two  three
# A    1    2      3
# B    4    5      6

# %%
data
# Out:
# array([(1, 2., b'Hello'), (2, 3., b'World')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
pd.DataFrame.from_records(data, index="C")
# Out:
#           A    B
# C
# b'Hello'  1  2.0
# b'World'  2  3.0

# %% [markdown]
# #### Column selection, addition, deletion

# %%
df["one"]
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
df["three"] = df["one"] * df["two"]

# %%
df["flag"] = df["one"] > 2
df
# Out:
#    one  two  three   flag
# a  1.0  1.0    1.0  False
# b  2.0  2.0    4.0  False
# c  3.0  3.0    9.0   True
# d  NaN  4.0    NaN  False

# %%
del df["two"]

# %%
three = df.pop("three")

# %%
df
# Out:
#    one   flag
# a  1.0  False
# b  2.0  False
# c  3.0   True
# d  NaN  False

# %%
df["foo"] = "bar"

# %%
df["one_trunc"] = df["one"][:2]
df
# Out:
#    one   flag  foo  one_trunc
# a  1.0  False  bar        1.0
# b  2.0  False  bar        2.0
# c  3.0   True  bar        NaN
# d  NaN  False  bar        NaN

# %%
df.insert(1, "bar", df["one"])
df
# Out:
#    one  bar   flag  foo  one_trunc
# a  1.0  1.0  False  bar        1.0
# b  2.0  2.0  False  bar        2.0
# c  3.0  3.0   True  bar        NaN
# d  NaN  NaN  False  bar        NaN

# %% [markdown]
# #### Assigning new columns in method chains

# %%
iris = pd.read_csv("/content/iris.csv", sep=",")

# %%
iris.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
iris.assign(sepal_ratio=iris["sepal.width"] / iris["sepal.length"]).head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  sepal_ratio
# 0           5.1          3.5           1.4          0.2  Setosa     0.686275
# 1           4.9          3.0           1.4          0.2  Setosa     0.612245
# 2           4.7          3.2           1.3          0.2  Setosa     0.680851
# 3           4.6          3.1           1.5          0.2  Setosa     0.673913
# 4           5.0          3.6           1.4          0.2  Setosa     0.720000

# %%
iris.assign(sepal_ratio=lambda x: (x["sepal.width"] / x["sepal.length"])).head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety  sepal_ratio
# 0           5.1          3.5           1.4          0.2  Setosa     0.686275
# 1           4.9          3.0           1.4          0.2  Setosa     0.612245
# 2           4.7          3.2           1.3          0.2  Setosa     0.680851
# 3           4.6          3.1           1.5          0.2  Setosa     0.673913
# 4           5.0          3.6           1.4          0.2  Setosa     0.720000

# %%
dfa = pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]})

# %%
dfa.assign(C=lambda x: x["A"] + x["B"], D=lambda x: x["A"] + x["C"])
# Out:
#    A  B  C   D
# 0  1  4  5   6
# 1  2  5  7   9
# 2  3  6  9  12

# %%
df
# Out:
#    one  bar   flag  foo  one_trunc
# a  1.0  1.0  False  bar        1.0
# b  2.0  2.0  False  bar        2.0
# c  3.0  3.0   True  bar        NaN
# d  NaN  NaN  False  bar        NaN

# %%
df.loc["b"]
# Out:
# one              2
# bar              2
# flag         False
# foo            bar
# one_trunc        2
# Name: b, dtype: object

# %%
df.iloc[2]
# Out:
# one             3
# bar             3
# flag         True
# foo           bar
# one_trunc     NaN
# Name: c, dtype: object

# %% [markdown]
# #### Data alignment and arithmetic

# %%
df = pd.DataFrame(np.random.randn(10, 4), columns=["A", "B", "C", "D"])

# %%
df2 = pd.DataFrame(np.random.randn(7, 3), columns=["A", "B", "C"])

# %%
df + df2
# Out:
#           A         B         C   D
# 0  0.006914  1.881791 -2.015725 NaN
# 1  2.472935 -4.297391 -0.433908 NaN
# 2 -0.668510 -1.261135  0.686843 NaN
# 3  0.739833 -1.285257  1.181780 NaN
# 4  1.224648  0.750078 -0.009136 NaN
# 5 -0.606018  0.745306  0.067958 NaN
# 6  0.664658  0.302075 -3.317737 NaN
# 7       NaN       NaN       NaN NaN
# 8       NaN       NaN       NaN NaN
# 9       NaN       NaN       NaN NaN

# %%
df - df.iloc[0]
# Out:
#           A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000
# 1 -0.363181 -3.437769 -0.713511  0.781606
# 2 -2.535524 -1.493632  1.175291  0.105351
# 3  0.354042 -1.657567  0.697810  0.048342
# 4  0.079830 -1.973177 -0.655256 -0.377716
# 5 -0.350462 -0.344171  0.006906  0.036296
# 6 -1.840961 -1.376630 -1.100366  0.857550
# 7 -0.736913 -1.651939  0.774469 -0.650274
# 8 -1.051425 -2.158612 -0.510721 -0.676927
# 9 -2.113190 -2.263936  2.556229  0.682292

# %%
df * 5 + 2
# Out:
#           A         B          C         D
# 0  8.169105  7.804442  -0.175998  0.501338
# 1  6.353198 -9.384400  -3.743553  4.409367
# 2 -4.508516  0.336283   5.700456  1.028093
# 3  9.939317 -0.483395   3.313050  0.743049
# 4  8.568256 -2.061440  -3.452276 -1.387243
# 5  6.416793  6.083587  -0.141467  0.682818
# 6 -1.035699  0.921291  -5.677826  4.789090
# 7  4.484542 -0.455253   3.696345 -2.750033
# 8  2.911983 -2.988615  -2.729605 -2.883295
# 9 -2.396847 -3.515235  12.605148  3.912797

# %%
1 / df
# Out:
#           A         B         C         D
# 0  0.810490  0.861409 -2.297796 -3.336309
# 1  1.148581 -0.439197 -0.870541  2.075233
# 2 -0.768224 -3.005319  1.351185 -5.144527
# 3  0.629777 -2.013373  3.807927 -3.977880
# 4  0.761237 -1.231090 -0.917048 -1.476127
# 5  1.132043  1.224414 -2.334848 -3.795984
# 6 -1.647067 -4.635169 -0.651226  1.792699
# 7  2.012443 -2.036450  2.947514 -1.052624
# 8  5.482561 -1.002282 -1.057171 -1.023899
# 9 -1.137178 -0.906580  0.471469  2.613973

# %%
df ** 4
# Out:
#           A          B          C         D
# 0  2.317441   1.816193   0.035872  0.008071
# 1  0.574584  26.875750   1.741176  0.053918
# 2  2.871097   0.012259   0.300014  0.001428
# 3  6.357004   0.060856   0.004756  0.003994
# 4  2.977970   0.435352   1.413941  0.210623
# 5  0.608903   0.444926   0.033648  0.004816
# 6  0.135880   0.002166   5.559977  0.096821
# 7  0.060969   0.058144   0.013249  0.814529
# 8  0.001107   0.990923   0.800607  0.909855
# 9  0.597978   1.480390  20.238901  0.021419

# %%
df1 = pd.DataFrame({"a": [1, 0, 1], "b": [0, 1, 1]}, dtype=bool)

# %%
df2 = pd.DataFrame({"a": [0, 1, 1], "b": [1, 1, 0]}, dtype=bool)

# %%
df1 & df2
# Out:
#        a      b
# 0  False  False
# 1  False   True
# 2   True  False

# %%
df1 | df2
# Out:
#       a     b
# 0  True  True
# 1  True  True
# 2  True  True

# %%
df1 ^ df2
# Out:
#        a      b
# 0   True   True
# 1   True  False
# 2  False   True

# %%
-df1
# Out:
#        a      b
# 0  False   True
# 1   True  False
# 2  False  False

# %% [markdown]
# #### Transposing

# %%
df.T
# Out:
#           0         1         2  ...         7         8         9
# A  1.233821  0.870640 -1.301703  ...  0.496908  0.182397 -0.879369
# B  1.160888 -2.276880 -0.332743  ... -0.491051 -0.997723 -1.103047
# C -0.435200 -1.148711  0.740091  ...  0.339269 -0.945921  2.121030
# D -0.299732  0.481873 -0.194381  ... -0.950007 -0.976659  0.382559
#
# [4 rows x 10 columns]

# %%
-df.T
# Out:
#           0         1         2  ...         7         8         9
# A -1.233821 -0.870640  1.301703  ... -0.496908 -0.182397  0.879369
# B -1.160888  2.276880  0.332743  ...  0.491051  0.997723  1.103047
# C  0.435200  1.148711 -0.740091  ... -0.339269  0.945921 -2.121030
# D  0.299732 -0.481873  0.194381  ...  0.950007  0.976659 -0.382559
#
# [4 rows x 10 columns]

# %%
df[:5].T
# Out:
#           0         1         2         3         4
# A  1.233821  0.870640 -1.301703  1.587863  1.313651
# B  1.160888 -2.276880 -0.332743 -0.496679 -0.812288
# C -0.435200 -1.148711  0.740091  0.262610 -1.090455
# D -0.299732  0.481873 -0.194381 -0.251390 -0.677449

# %%
np.exp(df.T)
# Out:
#           0         1         2  ...         7         8         9
# A  3.434327  2.388438  0.272068  ...  1.643632  1.200090  0.415045
# B  3.192769  0.102604  0.716954  ...  0.611983  0.368718  0.331858
# C  0.647135  0.317045  2.096127  ...  1.403921  0.388322  8.339720
# D  0.741016  1.619105  0.823344  ...  0.386738  0.376567  1.466032
#
# [4 rows x 10 columns]

# %% [markdown]
# #### DataFrame interoperability with NumPy functions

# %%
np.exp(df)
# Out:
#           A         B         C         D
# 0  3.434327  3.192769  0.647135  0.741016
# 1  2.388438  0.102604  0.317045  1.619105
# 2  0.272068  0.716954  2.096127  0.823344
# 3  4.893283  0.608548  1.300320  0.777719
# 4  3.719731  0.443841  0.336063  0.507911
# 5  2.419011  2.263059  0.651620  0.768407
# 6  0.544907  0.805943  0.215334  1.746857
# 7  1.643632  0.611983  1.403921  0.386738
# 8  1.200090  0.368718  0.388322  0.376567
# 9  0.415045  0.331858  8.339720  1.466032

# %%
np.asarray(df)
# Out:
# array([[ 1.23382105,  1.16088849, -0.4351996 , -0.29973247],
#        [ 0.87063966, -2.27688003, -1.14871067,  0.4818735 ],
#        [-1.30170319, -0.33274342,  0.74009118, -0.19438133],
#        [ 1.58786336, -0.49667899,  0.26261004, -0.2513902 ],
#        [ 1.31365128, -0.81228806, -1.0904552 , -0.67744856],
#        [ 0.88335865,  0.81671749, -0.42829337, -0.26343631],
#        [-0.60713981, -0.21574186, -1.53556513,  0.55781799],
#        [ 0.49690849, -0.49105066,  0.339269  , -0.95000655],
#        [ 0.18239652, -0.99772303, -0.94592105, -0.97665907],
#        [-0.87936942, -1.10304703,  2.12102962,  0.38255939]])

# %%
ser = pd.Series([1, 2, 3, 4])

# %%
np.exp(ser)
# Out:
# 0     2.718282
# 1     7.389056
# 2    20.085537
# 3    54.598150
# dtype: float64

# %%
ser1 = pd.Series([1, 2, 3], index=["a", "b", "c"])
ser1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
ser2 = pd.Series([1, 3, 5], index=["b", "a", "c"])
ser2
# Out:
# b    1
# a    3
# c    5
# dtype: int64

# %%
ser3 = pd.Series([2, 4, 6], index=["b", "c", "d"])
ser3
# Out:
# b    2
# c    4
# d    6
# dtype: int64

# %%
np.remainder(ser1, ser2)
# Out:
# a    1
# b    0
# c    3
# dtype: int64

# %%
np.remainder(ser1, ser3)
# Out:
# a    NaN
# b    0.0
# c    3.0
# d    NaN
# dtype: float64

# %%
ser = pd.Series([1, 2, 3])

# %%
idx = pd.Index([4, 5, 6])

# %%
np.maximum(ser, idx)
# Out:
# 0    4
# 1    5
# 2    6
# dtype: int64

# %% [markdown]
# #### Console display

# %%
baseball = pd.read_html("https://github.com/pandas-dev/pandas/blob/master/doc/data/baseball.csv")

# %%
baseball = pd.DataFrame(np.array(baseball).reshape(100,24))

# %%
baseball = baseball.dropna(axis='columns')

# %%
baseball.columns = ["id", "player","year", "stint", "team", "lg",	"g", 	
                    "ab", "r", "h", "X2b", "X3b", "hr","rbi","sb","cs", "bb", 
                    "so", "ibb", "hbp", "sh", "sf", "gidp"]

# %%
print(baseball)
# Out:
#        id     player  year stint team  lg    g  ...  bb  so ibb hbp sh sf gidp
# 0   88641  womacto01  2006     2  CHN  NL   19  ...   4   4   0   0  3  0    0
# 1   88643  schilcu01  2006     1  BOS  AL   31  ...   0   1   0   0  0  0    0
# 2   88645  myersmi01  2006     1  NYA  AL   62  ...   0   0   0   0  0  0    0
# 3   88649  helliri01  2006     1  MIL  NL   20  ...   0   2   0   0  0  0    0
# 4   88650  johnsra05  2006     1  NYA  AL   33  ...   0   4   0   0  0  0    0
# ..    ...        ...   ...   ...  ...  ..  ...  ...  ..  ..  ..  .. .. ..  ...
# 95  89525  benitar01  2007     2  FLO  NL   34  ...   0   0   0   0  0  0    0
# 96  89526  benitar01  2007     1  SFN  NL   19  ...   0   0   0   0  0  0    0
# 97  89530  ausmubr01  2007     1  HOU  NL  117  ...  37  74   3   6  4  1   11
# 98  89533   aloumo01  2007     1  NYN  NL   87  ...  27  30   5   2  0  3   13
# 99  89534  alomasa02  2007     1  NYN  NL    8  ...   0   3   0   0  0  0    0
#
# [100 rows x 23 columns]

# %%
baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 23 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      100 non-null    object
#  1   player  100 non-null    object
#  2   year    100 non-null    object
#  3   stint   100 non-null    object
#  4   team    100 non-null    object
#  5   lg      100 non-null    object
#  6   g       100 non-null    object
#  7   ab      100 non-null    object
#  8   r       100 non-null    object
#  9   h       100 non-null    object
#  10  X2b     100 non-null    object
#  11  X3b     100 non-null    object
#  12  hr      100 non-null    object
#  13  rbi     100 non-null    object
#  14  sb      100 non-null    object
#  15  cs      100 non-null    object
#  16  bb      100 non-null    object
#  17  so      100 non-null    object
#  18  ibb     100 non-null    object
#  19  hbp     100 non-null    object
#  20  sh      100 non-null    object
#  21  sf      100 non-null    object
#  22  gidp    100 non-null    object
# dtypes: object(23)
# memory usage: 18.1+ KB

# %%
print(baseball.iloc[-20:, :12].to_string())
# Out:
#        id     player  year stint team  lg    g   ab   r    h X2b X3b
# 80  89474  finlest01  2007     1  COL  NL   43   94   9   17   3   0
# 81  89480  embreal01  2007     1  OAK  AL    4    0   0    0   0   0
# 82  89481  edmonji01  2007     1  SLN  NL  117  365  39   92  15   2
# 83  89482  easleda01  2007     1  NYN  NL   76  193  24   54   6   0
# 84  89489  delgaca01  2007     1  NYN  NL  139  538  71  139  30   0
# 85  89493  cormirh01  2007     1  CIN  NL    6    0   0    0   0   0
# 86  89494  coninje01  2007     2  NYN  NL   21   41   2    8   2   0
# 87  89495  coninje01  2007     1  CIN  NL   80  215  23   57  11   1
# 88  89497  clemero02  2007     1  NYA  AL    2    2   0    1   0   0
# 89  89498  claytro01  2007     2  BOS  AL    8    6   1    0   0   0
# 90  89499  claytro01  2007     1  TOR  AL   69  189  23   48  14   0
# 91  89501  cirilje01  2007     2  ARI  NL   28   40   6    8   4   0
# 92  89502  cirilje01  2007     1  MIN  AL   50  153  18   40   9   2
# 93  89521  bondsba01  2007     1  SFN  NL  126  340  75   94  14   0
# 94  89523  biggicr01  2007     1  HOU  NL  141  517  68  130  31   3
# 95  89525  benitar01  2007     2  FLO  NL   34    0   0    0   0   0
# 96  89526  benitar01  2007     1  SFN  NL   19    0   0    0   0   0
# 97  89530  ausmubr01  2007     1  HOU  NL  117  349  38   82  16   3
# 98  89533   aloumo01  2007     1  NYN  NL   87  328  51  112  19   1
# 99  89534  alomasa02  2007     1  NYN  NL    8   22   1    3   1   0

# %%
pd.DataFrame(np.random.randn(3, 12))
# Out:
#          0         1         2   ...        9         10        11
# 0  0.250853  1.431953  0.552806  ...  0.582859 -1.126450 -0.289878
# 1 -0.201291 -0.718561  1.045974  ...  0.498057 -0.852119 -1.277786
# 2  1.283650  0.454842  0.319881  ...  0.483111 -0.482583 -0.500384
#
# [3 rows x 12 columns]

# %%
pd.set_option("display.width", 40)  # default is 80

# %%
pd.DataFrame(np.random.randn(3, 12))
# Out:
#          0         1         2   ...        9         10        11
# 0  0.615732  2.087216 -0.736052  ...  1.663352 -0.460880  0.849998
# 1  0.470689 -1.915351  2.105857  ...  1.063019 -0.790552 -0.550533
# 2 -1.040690  0.051813  0.076399  ...  1.262754 -0.043311 -1.768993
#
# [3 rows x 12 columns]

# %%
datafile = {
    "filename": ["filename_01", "filename_02"],
    "path": [
             "media/user_name/storage/folder_01/filename_01",
             "media/user_name/storage/folder_02/filename_02",
    ],             
}

# %%
pd.set_option("display.max_colwidth", 30)

# %%
pd.DataFrame(datafile)
# Out:
#       filename                           path
# 0  filename_01  media/user_name/storage/fo...
# 1  filename_02  media/user_name/storage/fo...

# %%
pd.set_option("display.max_colwidth", 100)

# %%
pd.DataFrame(datafile)
# Out:
#       filename                                           path
# 0  filename_01  media/user_name/storage/folder_01/filename_01
# 1  filename_02  media/user_name/storage/folder_02/filename_02
