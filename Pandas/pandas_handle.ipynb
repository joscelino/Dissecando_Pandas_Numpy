# %% [markdown]
# ## Importacao de bibliotecas

# %%
import pandas as pd

# %% [markdown]
# ## Trabalhando com os dados

# %%
# Criacao do dataframe
df = pd.DataFrame(
   {
    "Name": [
   "Braund, Mr. Owen Harris",
   "Allen, Mr. William Henry",
   "Bonnell, Miss. Elizabeth",
   ],
   "Age": [22, 35, 58],
   "Sex": ["male", "male", "female"],
   }
   )

# %%
# Visualizacao do DF
df

# %%
# Trabalhando apenas com um atributo
df["Age"]

# %%
# Criando uma serie com as idades
ages = pd.Series(df["Age"], name="Age")

# %%
ages

# %% [markdown]
# ## Analise descritiva basica

# %%
df["Age"].max()

# %%
ages.max()

# %%
df.describe()
