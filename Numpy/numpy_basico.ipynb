# %% [markdown]
# ## Importacao das bibliotecas

# %%
import numpy as np

# %% [markdown]
# ## Trabalhando os metodos

# %%
a = np.arange(15).reshape(3, 5)

# %%
a

# %%
a.shape

# %%
a.ndim

# %%
a.dtype.name

# %%
a.itemsize

# %%
a.size

# %%
type(a)

# %%
b = np.array([6, 7, 8])

# %%
b

# %%
type(b)
